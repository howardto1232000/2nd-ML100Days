# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

datPath = 'E:\\Documents\\2nd-ML100Days\\D2\\data\\application_train.csv'
df = pd.read_csv(datPath)

# %%
num_col = len(df.columns)
num_row = len(df.index)
print(num_col, num_row)
# Out:
# 122 307511

# %%
# print(df.info)
# first 3 row
print(df.head(3))
# last 3 row
print(df.tail(3))
df = df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 0             ...                             0                0
# 1             ...                             0                0
# 2             ...                             0                0
#
#   FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0                0                0                        0.0
# ...

# %%
df.describe()
# Out:
#           SK_ID_CURR    TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# count       5.000000  5.000000           5.0          5.000000  5.000000e+00
# mean   100004.400000  0.200000           0.0     159300.000000  5.321565e+05
# std         2.073644  0.447214           0.0      78369.796478  4.476835e+05
# min    100002.000000  0.000000           0.0      67500.000000  1.350000e+05
# 25%    100003.000000  0.000000           0.0     121500.000000  3.126825e+05
# 50%    100004.000000  0.000000           0.0     135000.000000  4.065975e+05
# 75%    100006.000000  0.000000           0.0     202500.000000  5.130000e+05
# max    100007.000000  1.000000           0.0     270000.000000  1.293502e+06
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# count      5.000000     5.000000e+00                    5.000000
# mean   23740.200000     4.851000e+05                    0.013811
# std    10856.599316     3.846960e+05                    0.009985
# ...

# %%
df.iloc[:5, :5]
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N

# %%
df.dtypes
# Out:
# SK_ID_CURR                      int64
# TARGET                          int64
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# CNT_CHILDREN                    int64
# AMT_INCOME_TOTAL              float64
# AMT_CREDIT                    float64
# AMT_ANNUITY                   float64
# AMT_GOODS_PRICE               float64
# NAME_TYPE_SUITE                object
# NAME_INCOME_TYPE               object
# NAME_EDUCATION_TYPE            object
# NAME_FAMILY_STATUS             object
# NAME_HOUSING_TYPE              object
# REGION_POPULATION_RELATIVE    float64
# DAYS_BIRTH                      int64
# DAYS_EMPLOYED                   int64
# DAYS_REGISTRATION             float64
# DAYS_ID_PUBLISH                 int64
# OWN_CAR_AGE                   float64
# FLAG_MOBIL                      int64
# FLAG_EMP_PHONE                  int64
# FLAG_WORK_PHONE                 int64
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (5, 122)

# %%
df.size
# Out:
# 610

# %%
df.columns[0]
# Out:
# 'SK_ID_CURR'

# %%
s = df['AMT_INCOME_TOTAL'] # select col to Series
df[['AMT_INCOME_TOTAL']] # select col to df
df[['AMT_INCOME_TOTAL','NAME_CONTRACT_TYPE']] # select 2 or more
df[['NAME_CONTRACT_TYPE', 'AMT_INCOME_TOTAL']]# change order 改变排序了
s = df[df.columns[0]] # select by number
f = df[df.columns[[0, 3, 4]]] # by number
print(f)
s = df.pop('SK_ID_CURR')
print(s)
# Out:
#    SK_ID_CURR CODE_GENDER FLAG_OWN_CAR
# 0      100002           M            N
# 1      100003           F            N
# 2      100004           M            Y
# 3      100006           F            N
# 4      100007           M            N
# 0    100002
# 1    100003
# 2    100004
# 3    100006
# 4    100007
# Name: SK_ID_CURR, dtype: int64

# %%
df.iloc[:, [0, 1, 2]]
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER
# 0       1         Cash loans           M
# 1       0         Cash loans           F
# 2       0    Revolving loans           M
# 3       0         Cash loans           F
# 4       0         Cash loans           M

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-df29dd68123d> in <module>()
# ----> 1 df.sort()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
